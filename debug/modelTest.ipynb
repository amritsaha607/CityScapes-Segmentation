# %%
import sys
sys.path.append('../')

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, Flatten, Convolution2D, MaxPooling2D, UpSampling2D, Concatenate
# from keras.layers.convolutional import Conv2D
from tensorflow.keras.layers import Conv2D

# %%
nr = 2
ip = Input((256, 256, 3))
conv1 = Conv2D(64/nr, 3, activation='relu', padding='same', kernel_initializer='he_normal')(ip)

# %%
from models.CustomModel import CustomModel

# %%
model = CustomModel()

# %%
model.__dir__()
# Out:
# ['_self_setattr_tracking',
#  '_trainable',
#  '_stateful',
#  'built',
#  '_build_input_shape',
#  '_input_spec',
#  'supports_masking',
#  '_supports_ragged_inputs',
#  '_name',
#  '_activity_regularizer',
#  '_trainable_weights',
#  '_non_trainable_weights',
#  '_updates',
#  '_thread_local',
#  '_callable_losses',
#  '_losses',
#  '_metrics',
#  '_metrics_lock',
#  '_dtype_policy',
#  '_dtype_defaulted_to_floatx',
#  '_autocast',
#  '_layers',
#  '_inbound_nodes',
#  '_outbound_nodes',
#  '_expects_training_arg',
#  '_expects_mask_arg',
#  '_dynamic',
#  '_initial_weights',
#  '_auto_track_sub_layers',
#  'output_names',
#  'input_names',
#  '_is_compiled',
#  '_saved_model_inputs_spec',
#  '_compute_output_and_mask_jointly',
#  'optimizer',
#  '_scope',
#  '_reuse',
#  '_graph',
#  '_trackable_saver',
#  '_is_graph_network',
#  'outputs',
#  'inputs',
#  '_obj_reference_counts_dict',
#  '_distribution_strategy',
#  '_run_eagerly',
#  'stop_training',
#  'train_function',
# ...
