# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /root/
# %mkdir .kaggle
# %cd /content/drive/My\ Drive/Works/Segmentation/Cityscapes/
# %cp kaggle.json /root/.kaggle/

# %cd /content/
# %mkdir data/
# %cd data/
# !kaggle datasets download -d dansbecker/cityscapes-image-pairs
# !unzip cityscapes-image-pairs.zip
# %rm cityscapes-image-pairs.zip

# %%
# %cd /content/drive/My Drive/Works/Segmentation/Cityscapes/debug
# Out:
# /content/drive/My Drive/Works/Segmentation/Cityscapes/debug

# %%
import sys
sys.path.append('../')

# %%
import os
import tensorflow as tf
from data.dataset import Dataset
from models.unet import UNet
# Out:
# Using TensorFlow backend.

# %%
N_EPOCHS = 100
batch_size = 1
data_root = '/content/data/cityscapes_data'

train_dir = os.path.join(data_root, 'train')
val_dir = os.path.join(data_root, 'val')

# %%
train_set, val_set = Dataset(train_dir), Dataset(val_dir)
_, x_train, y_train = train_set.getData()
val_mage_paths, x_val, y_val = val_set.getData()

# %%
print(x_train.shape, y_train.shape)
# Out:
# (2975, 256, 256, 3) (2975, 256, 256, 3)

# %%
model = UNet()

# %%
hist = model.fit(
	x_train, y_train,
	validation_data=(x_val, y_val),
	epochs=N_EPOCHS,
	batch_size=batch_size,
	verbose=1,
)
